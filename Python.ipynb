# %% [markdown]
# ## **PYTHON**

# %% [markdown]
# **Q1.**

# %%
def highestfreq(str):
    words = str.split()
    wordfreq = {}

    for i in words:
        if i in wordfreq:
            wordfreq[i] += 1

        else:
            wordfreq[i] = 1

    maxfreq = max(wordfreq.values())
    for i, j in wordfreq.items():
        if j == maxfreq:
            return len(i)

# %%
highestfreq("write write write all the number from from from 1 to 100")
# Out:
# 5

# %% [markdown]
# From the given string we can see that the most frequent words are `write` and `from` and the highest frequency word is `write` with the length of `5`.

# %%
highestfreq("run run there is an an an an aligator")
# Out:
# 2

# %% [markdown]
# From the given string we can see that the most frequent words are `run` and `an` and the highest frequency word is `an` with the length of `2`.

# %% [markdown]
# **Q2.**

# %%
from collections import Counter

def validstr(s):
    countfreq = Counter(s)
    frequency = set(countfreq.values())

    if len(frequency) == 1:
        return "YES"
    else:
        return "NO"

# %%
validstr("abc")
# Out:
# 'YES'

# %%
validstr("aabbcdd")
# Out:
# 'NO'

# %% [markdown]
# **Q3.**

# %%
import pandas as pd
import requests

def toexcel(link, filename):
    response = requests.get(link)
    data = response.json()
    data = data['pokemon']

    newdata = pd.DataFrame(data)
    newdata.to_excel(filename, index=False)

    return newdata

pokemon = toexcel('https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json',"pokemon.xlsx")

# %% [markdown]
# **Q4.**

# %%
import pandas as pd
import requests

def tocsv(link):
    
    # get the data from the provided link
    response = requests.get(link)
    data = response.json()
    return data

data = tocsv("https://data.nasa.gov/resource/y77d-th95.json")
df = pd.DataFrame(data)
df.to_csv("nasadata.csv", index=False)

# %% [markdown]
# **Q5.**

# %%
def fromurl(link):
    response = requests.get(link)
    data = response.json()

    return data

data = fromurl("http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes")

# %% [markdown]
# **Q6.**

# %%
import pandas as pd

df = pd.read_excel("pokemon.xlsx")
df.head()
# Out:
#    id  num        name                                               img  \
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#                   type  height    weight             candy  candy_count  \
# 0  ['Grass', 'Poison']  0.71 m    6.9 kg   Bulbasaur Candy         25.0
# 1  ['Grass', 'Poison']  0.99 m   13.0 kg   Bulbasaur Candy        100.0
# 2  ['Grass', 'Poison']  2.01 m  100.0 kg   Bulbasaur Candy          NaN
# 3             ['Fire']  0.61 m    8.5 kg  Charmander Candy         25.0
# 4             ['Fire']  1.09 m   19.0 kg  Charmander Candy        100.0
#
#            egg  spawn_chance  avg_spawns spawn_time multipliers  \
# ...

# %%
# Get all Pokemons whose spawn rate is less than 5%

spawnrate = df[df['avg_spawns'] < 5]
spawnrate
# Out:
#       id  num        name                                               img  \
# 1      2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 4      5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 7      8    8   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# ..   ...  ...         ...                                               ...
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 147  148  148   Dragonair  http://www.serebii.net/pokemongo/pokemon/148.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
# ...

# %%
# Plot the distribution of spawn rates

import matplotlib.pyplot as plt

plt.hist(df['avg_spawns'], bins=20, edgecolor='black')
plt.xlabel('Spawn Chance Rate')
plt.ylabel('Frequency')
plt.title('Distribution of Pokémon Spawn Rates')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Get all Pokemons that have less than 4 weaknesses

# Using ast library to convert string to list and then fetch the len for weakness less than 4
import ast

df["weaknesses"] = df["weaknesses"].apply(ast.literal_eval)
weaknessless4 = df[df['weaknesses'].apply(lambda x: len(x) < 4)]
weaknessless4.loc[:,["name","weaknesses"]]
# Out:
#            name               weaknesses
# 3    Charmander    [Water, Ground, Rock]
# 4    Charmeleon    [Water, Ground, Rock]
# 5     Charizard  [Water, Electric, Rock]
# 6      Squirtle        [Electric, Grass]
# 7     Wartortle        [Electric, Grass]
# ..          ...                      ...
# 145     Moltres  [Water, Electric, Rock]
# 146     Dratini     [Ice, Dragon, Fairy]
# 147   Dragonair     [Ice, Dragon, Fairy]
# 149      Mewtwo       [Bug, Ghost, Dark]
# 150         Mew       [Bug, Ghost, Dark]
#
# [102 rows x 2 columns]

# %%
# Get all Pokemons that have no multipliers at all

df[df['multipliers'].isna()]
# Out:
#       id  num        name                                               img  \
# 2      3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 5      6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 8      9    9   Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 11    12   12  Butterfree  http://www.serebii.net/pokemongo/pokemon/012.png
# 14    15   15    Beedrill  http://www.serebii.net/pokemongo/pokemon/015.png
# ..   ...  ...         ...                                               ...
# 144  145  145      Zapdos  http://www.serebii.net/pokemongo/pokemon/145.png
# 145  146  146     Moltres  http://www.serebii.net/pokemongo/pokemon/146.png
# 148  149  149   Dragonite  http://www.serebii.net/pokemongo/pokemon/149.png
# 149  150  150      Mewtwo  http://www.serebii.net/pokemongo/pokemon/150.png
# 150  151  151         Mew  http://www.serebii.net/pokemongo/pokemon/151.png
#
# ...

# %%
#  Get all Pokemons that do not have more than 2 evolutions

evolution = df["next_evolution"].dropna().apply(ast.literal_eval).apply(lambda x: [evolution['name'] for evolution in x])

for i in evolution:
    if len(i) <= 2:
        print(i, end=" ")
# Out:
# ['Ivysaur', 'Venusaur'] ['Venusaur'] ['Charmeleon', 'Charizard'] ['Charizard'] ['Wartortle', 'Blastoise'] ['Blastoise'] ['Metapod', 'Butterfree'] ['Butterfree'] ['Kakuna', 'Beedrill'] ['Beedrill'] ['Pidgeotto', 'Pidgeot'] ['Pidgeot'] ['Raticate'] ['Fearow'] ['Arbok'] ['Raichu'] ['Sandslash'] ['Nidorina', 'Nidoqueen'] ['Nidoqueen'] ['Nidorino', 'Nidoking'] ['Nidoking'] ['Clefable'] ['Ninetales'] ['Wigglytuff'] ['Golbat'] ['Gloom', 'Vileplume'] ['Vileplume'] ['Parasect'] ['Venomoth'] ['Dugtrio'] ['Persian'] ['Golduck'] ['Primeape'] ['Arcanine'] ['Poliwhirl', 'Poliwrath'] ['Poliwrath'] ['Kadabra', 'Alakazam'] ['Alakazam'] ['Machoke', 'Machamp'] ['Machamp'] ['Weepinbell', 'Victreebel'] ['Victreebel'] ['Tentacruel'] ['Graveler', 'Golem'] ['Golem'] ['Rapidash'] ['Slowbro'] ['Magneton'] ['Dodrio'] ['Dewgong'] ['Muk'] ['Cloyster'] ['Haunter', 'Gengar'] ['Gengar'] ['Hypno'] ['Kingler'] ['Electrode'] ['Exeggutor'] ['Marowak'] ['Weezing'] ['Rhydon'] ['Seadra'] ['Seaking'] ['Starmie'] ['Gyarados
# ...

# %%
#  Get all Pokemons whose spawn time is less than 300 seconds

df["spawn_time"] = pd.to_datetime(df["spawn_time"],format='%H:%M')
threshold = pd.Timedelta(seconds=300)
spawn_time = df[df['spawn_time'].diff() < threshold]
spawn_time.loc[:,["name"]]
# Out:
#            name
# 1       Ivysaur
# 3    Charmander
# 5     Charizard
# 6      Squirtle
# 8     Blastoise
# ..          ...
# 136     Porygon
# 138     Omastar
# 139      Kabuto
# 141  Aerodactyl
# 142     Snorlax
#
# [65 rows x 1 columns]

# %%
# Get all Pokemon who have more than two types of capabilities

df['type'] = df['type'].apply(ast.literal_eval)
df[df['type'].apply(lambda i : len(i)>2)]
# Out:
# Empty DataFrame
# Columns: [id, num, name, img, type, height, weight, candy, candy_count, egg, spawn_chance, avg_spawns, spawn_time, multipliers, weaknesses, next_evolution, prev_evolution]
# Index: []

# %% [markdown]
# **Q7.**

# %%
df1 = pd.read_csv("nasadata.csv")
df1.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....
#
# ...

# %%
# Get all the Earth meteorites that fell before the year 2000

df1['year_extracted'] = df1['year'].str[:4]
df1[(df1['fall'] == 'Fell') & (df1['year_extracted'] < '2000')]
# Out:
#           name     id nametype     recclass      mass  fall  \
# 0       Aachen      1    Valid           L5      21.0  Fell
# 1       Aarhus      2    Valid           H6     720.0  Fell
# 2         Abee      6    Valid          EH4  107000.0  Fell
# 3     Acapulco     10    Valid  Acapulcoite    1914.0  Fell
# 4      Achiras    370    Valid           L6     780.0  Fell
# ..         ...    ...      ...          ...       ...   ...
# 994   Timochin  24004    Valid           H5   65500.0  Fell
# 995   Tirupati  24009    Valid           H6     230.0  Fell
# 997      Tjabe  24011    Valid           H6   20000.0  Fell
# 998   Tjerebon  24012    Valid           L5   16500.0  Fell
# 999  Tomakovka  24019    Valid          LL6     600.0  Fell
#
#                         year    reclat    reclong  \
# 0    1880-01-01T00:00:00.000  50.77500    6.08333
# 1    1951-01-01T00:00:00.000  56.18333   10.23333
# 2    1952-01-01T00:00:00.000  54.21667 -113.00000
# ...

# %%
# Get all the earth meteorites co-ordinates who fell before the year 1970

#df1.dropna(inplace=True)

df1['year_extracted'] = df1['year'].str[:4]
before1970 = df1[(df1['fall'] == 'Fell') & (df1['year_extracted']<'1970')]

# %%
before1970.loc[:,["year_extracted","coordinates"]]
# Out:
#     year_extracted            coordinates
# 28            1899  [-85.88333, 42.53333]
# 34            1898     [-70.75, 44.61667]
# 46            1932          [-94.3, 38.5]
# 54            1933           [-87, 34.75]
# 55            1945     [-96.15, 34.31667]
# ..             ...                    ...
# 946           1950      [-90.23333, 38.7]
# 948           1919  [-76.38333, 38.16667]
# 962           1924  [-90.66667, 36.48333]
# 970           1954   [-86.2945, 33.18836]
# 992           1927      [-89.68333, 38.2]
#
# [106 rows x 2 columns]

# %%
# Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

mass = df1[df1["mass"] > 10000]
mass.loc[:,["name","mass"]]
# Out:
#                         name       mass
# 28                   Allegan    32000.0
# 84                      Bath    21000.0
# 85              Bath Furnace    86000.0
# 89                 Beardsley    16000.0
# 158              Cabin Creek    48500.0
# 209        Colby (Wisconsin)   104000.0
# 220         Cumberland Falls    17000.0
# 291              Estherville   320000.0
# 292               Farmington    89400.0
# 293                Farmville    56000.0
# 301                   Fisher    17600.0
# 303              Forest City   152000.0
# 307                  Forsyth    16300.0
# 380                 Holbrook   220000.0
# 382                Homestead   230000.0
# 422                Johnstown    40300.0
# 533                   Leedey    51500.0
# 552                Lost City    17000.0
# 591            Marion (Iowa)    28400.0
# 626        Miller (Arkansas)    16700.0
# 635             Modoc (1905)    35000.0
# 663                   Murray    12600.0
# ...

# %% [markdown]
# **Q8.**

# %%
import requests

def apitocsv(url):
    response = requests.get(url)
    data = response.json()

    # Extract episode details
    episodes = data["_embedded"]["episodes"]

    # Convert episode data to DataFrame
    df2 = pd.DataFrame(episodes)

    df2.to_csv("output.csv", index=False)

# %%
url = "http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes"
apitocsv(url)
df2 = pd.read_csv("output.csv")
df2.head()
# Out:
#        id                                                url  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type     airdate airtime  \
# 0       The Original       1       1  regular  2016-10-02   21:00
# 1           Chestnut       1       2  regular  2016-10-09   21:00
# 2          The Stray       1       3  regular  2016-10-16   21:00
# 3  Dissonance Theory       1       4  regular  2016-10-23   21:00
# 4        Contrapasso       1       5  regular  2016-10-30   21:00
#
#                     airstamp  runtime            rating  \
# 0  2016-10-03T01:00:00+00:00       68    {'average': 8}
# 1  2016-10-10T01:00:00+00:00       60  {'average': 7.7}
# ...

# %%
#  Get all the overall ratings for each season and using plots compare the ratings for all the seasons, like season 1 ratings, season 2, and so on.

import ast
df2["rating"] = df2["rating"].apply(lambda x: ast.literal_eval(x)['average'] if isinstance(x, str) else x)


season_ratings = df2.groupby("season")["rating"].mean()
season_ratings
# Out:
# season
# 1    8.0900
# 2    8.0000
# 3    7.7750
# 4    7.5375
# Name: rating, dtype: float64

# %%
season_ratings.plot(kind="bar", xlabel="Season", ylabel="Rating", title="Ratings by Season")
# Out:
# <AxesSubplot:title={'center':'Ratings by Season'}, xlabel='Season', ylabel='Rating'>

# %%
# Get all the episode names, whose average rating is more than 8 for every season

df2["rating"] = df2["rating"].apply(lambda x: ast.literal_eval(x)['average'] if isinstance(x, str) else x)
df2['name'][df2["rating"]>8.0]
# Out:
# 6                 Trompe L'Oeil
# 8     The Well-Tempered Clavier
# 9            The Bicameral Mind
# 17                      Kiksuya
# 18              Vanishing Point
# 19                The Passenger
# Name: name, dtype: object

# %%
# Get all the episode names that aired before May 2019

df2['year']=df2['airdate'].apply(lambda x : int(x.split("-")[0]))
df2['name'][df2['year'] < 2019]
# Out:
# 0                  The Original
# 1                      Chestnut
# 2                     The Stray
# 3             Dissonance Theory
# 4                   Contrapasso
# 5                 The Adversary
# 6                 Trompe L'Oeil
# 7                   Trace Decay
# 8     The Well-Tempered Clavier
# 9            The Bicameral Mind
# 10           Journey Into Night
# 11                      Reunion
# 12              Virtù e Fortuna
# 13     The Riddle of the Sphinx
# 14                 Akane No Mai
# 15                  Phase Space
# 16                 Les Écorchés
# 17                      Kiksuya
# 18              Vanishing Point
# 19                The Passenger
# Name: name, dtype: object

# %%
# Get the summary for the most popular ( ratings ) episode in every season

df2["popular"] = pd.Series(list(dict(df2.groupby(["summary"])["rating"].sum() > 8).values()))
df2.loc[df2["popular"] == True]["summary"]
# Out:
# 2     <p>Bernard continues to investigate Dolores' s...
# 4     <p>Dolores takes the first step on her path of...
# 8     <p>Bernard forces Robert to take him back into...
# 23        <p>The truth doesn't always set you free.</p>
# 24                                  <p>Just say no.</p>
# 32                                 <p>God is bored.</p>
# Name: summary, dtype: object

# %% [markdown]
# **Q9.**

# %%
import pandas as pd
df3 = pd.read_csv("https://data.wa.gov/api/views/f6w7-q2d2/rows.csv")
df3.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
# Get all the cars and their types that do not qualify for clean alternative fuel vehicle

df3[df3['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Not eligible due to low battery range'][['Make','Model']]
# Out:
#           Make        Model
# 6         FORD       FUSION
# 7         AUDI         Q5 E
# 8         FORD        C-MAX
# 14        FORD        C-MAX
# 15         KIA         NIRO
# ...        ...          ...
# 130377     BMW         530E
# 130385    AUDI           A3
# 130390    JEEP     WRANGLER
# 130407  TOYOTA  PRIUS PRIME
# 130437     BMW         530E
#
# [16446 rows x 2 columns]

# %%
# Get all TESLA cars with the model year, and model type made in Bothell City

df3[(df3['City']=='Bothell') & (df3['Make']=='TESLA')][['Model Year','Model']]
# Out:
#         Model Year    Model
# 39            2020  MODEL 3
# 217           2022  MODEL 3
# 218           2022  MODEL Y
# 222           2018  MODEL 3
# 292           2017  MODEL X
# ...            ...      ...
# 129778        2019  MODEL 3
# 129954        2021  MODEL 3
# 129976        2014  MODEL S
# 130295        2022  MODEL 3
# 130392        2018  MODEL 3
#
# [2407 rows x 2 columns]

# %%
# Get all the cars that have an electric range of more than 100, and were made after 2015

df3[(df3['Electric Range'] > 100) & (df3['Model Year'] > 2015)]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %%
# Draw plots to show the distribution between city and electric vehicle type

ev = df3[df3["Electric Vehicle Type"] == "Battery Electric Vehicle (BEV)"]
elv =  ev.loc[:,["City","Electric Vehicle Type"]]

import matplotlib.pyplot as plt

# Group the data by City and Electric Vehicle Type and count the occurrences
counts = elv.groupby(['City', 'Electric Vehicle Type']).size().unstack()[:20]

# Create a bar plot
counts.plot(kind='bar', stacked=True)
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Distribution of Electric Vehicle Types in Cities')
plt.legend(title='Electric Vehicle Type')
plt.show()

# %% [markdown]
# **Q10.**

# %%
import re

def count_pos_tags(text):
    # Count verbs
    verbs = re.findall(r'\b\w+ing\b|\b\w+ed\b|\b\w+s\b', text)
    verb_count = len(verbs)
    
    # Count nouns
    nouns = re.findall(r'\b\w+s\b|\b\w+[^inged]s\b|\b\w+[^ing]ing\b|\b\w+ed\b', text)
    noun_count = len(nouns)
    
    # Count pronouns
    pronouns = re.findall(r'\b(?:he|she|it|they|we|you|I|me|him|her|us|them)\b', text, re.IGNORECASE)
    pronoun_count = len(pronouns)
    
    # Count adjectives
    adjectives = re.findall(r'\b\w+ful\b|\b\w+ous\b|\b\w+ish\b|\b\w+ive\b', text)
    adjective_count = len(adjectives)
    
    # Create a dictionary with the counts
    pos_counts = {
        'Verbs': verb_count,
        'Nouns': noun_count,
        'Pronouns': pronoun_count,
        'Adjectives': adjective_count
    }
    
    return pos_counts

# %%
print(count_pos_tags("I am probably lazy."))
# Out:
# {'Verbs': 0, 'Nouns': 0, 'Pronouns': 1, 'Adjectives': 0}

# %%
print(count_pos_tags("I need to complete this assignments as soon as possible."))
# Out:
# {'Verbs': 5, 'Nouns': 5, 'Pronouns': 1, 'Adjectives': 0}
